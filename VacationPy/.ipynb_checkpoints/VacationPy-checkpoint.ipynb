# %%
import gmaps
from config import gkey
gmaps.configure(api_key=gkey)
from config import api_key
import requests
import json
import pandas as pd
from pprint import pprint

# %%
city_id = []
from csv import reader
with open("log.csv", 'r', encoding='UTF-8') as reading_object:
    csv_reader = reader(reading_object)
    next(csv_reader)
    for i in csv_reader:
        city_id.append(i[2])

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
response_list = []
unit = 'Imperial'
for x in city_id:
    base_url = url + "id=" + str(x) + "&appid=" + api_key + "&units=" + unit
    response = requests.get(base_url).json()
    response_list.append(response)

# %%
response_list
# Out:
# [{'coord': {'lon': -67.8, 'lat': -2.87},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 84.51,
#    'feels_like': 93.99,
#    'temp_min': 84.51,
#    'temp_max': 84.51,
#    'pressure': 1009,
#    'humidity': 73,
#    'sea_level': 1009,
#    'grnd_level': 1002},
#   'wind': {'speed': 1.41, 'deg': 106},
#   'rain': {'1h': 0.29},
#   'clouds': {'all': 45},
#   'dt': 1592858734,
#   'sys': {'country': 'BR', 'sunrise': 1592822077, 'sunset': 1592865115},
#   'timezone': -14400,
#   'id': 3661894,
#   'name': 'Tonantins',
#   'cod': 200},
#  {'coord': {'lon': -67.94, 'lat': -3.1},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 83.35,
#    'feels_like': 93.16,
#    'temp_min': 83.35,
#    'temp_max': 83.35,
#    'pressure': 1009,
#    'humidity': 79,
#    'sea_level': 1009,
# ...

# %%
coord = []
hum = []
for x in response_list:
    coord.append((float(x['coord']['lon']), float(x['coord']['lat']) ) )
    hum.append(int(x['main']['humidity']) )

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
fig.add_layer(gmaps.heatmap_layer(coord, weights=hum))

# %%
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
best_weather = []
best_weather_coord = []
for x in response_list:
    if 75 >= float(x['main']['temp_max']) >= 70 and float(x['wind']['speed']) < 5 and float(x['main']['humidity']) <= 40 \
    and float(x['clouds']['all'])==0:
        best_weather.append(x['name'])
        best_weather_coord.append(  x['coord']   ) 
print(best_weather)
print(best_weather_coord)
lat = best_weather_coord[0]['lat']
print(lat)
lon = best_weather_coord[0]['lon']
print(lon)
# Out:
# ['Sestino', "Sant'Angelo in Vado", 'San Giustino', 'Piandimeleto', 'Peglio', 'Mercatello sul Metauro', 'Lunano', 'Borgo Pace', "Belforte all'Isauro", 'Apecchio']
# [{'lon': 12.3, 'lat': 43.71}, {'lon': 12.42, 'lat': 43.67}, {'lon': 12.17, 'lat': 43.55}, {'lon': 12.41, 'lat': 43.72}, {'lon': 12.5, 'lat': 43.7}, {'lon': 12.34, 'lat': 43.65}, {'lon': 12.44, 'lat': 43.73}, {'lon': 12.29, 'lat': 43.66}, {'lon': 12.38, 'lat': 43.72}, {'lon': 12.42, 'lat': 43.56}]
# 43.71
# 12.3

# %%
counts = 0
hotel_data=[]
for x in best_weather_coord:
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
    "location": str(x['lat']) + "," + str(x['lon']),
#     "query": "Best Hotel",
    "keyword": "hotel",
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}
    response = requests.get(base_url, params=params).json()
    if response['results'] != []:
        hotel_data.append(response)

# %%
pprint(hotel_data)
# Out:
# [{'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 43.756466, 'lng': 12.356572},
#                             'viewport': {'northeast': {'lat': 43.75780487989272,
#                                                        'lng': 12.35791697989272},
#                                          'southwest': {'lat': 43.75510522010727,
#                                                        'lng': 12.35521732010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'b5f4a35d97d461a102eac1d887d174121249ec2d',
#                'name': 'Agriturismo Montefiorentino',
#                'photos': [{'height': 5312,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/102365651893176029720">Linda '
# ...

# %%
h_name = []
h_city = []
h_loc = []
for x in hotel_data:
    h_name.append(x['results'][0]['name'])
    h_city.append(x['results'][0]['plus_code']['compound_code'])
    h_loc.append((float( x['results'][0]['geometry']['location']['lat'] ) , float( x['results'][0]['geometry']['location']['lng'] ) ))

# %%
print(h_name)
print(h_city)
print(h_loc)
# Out:
# ['Agriturismo Montefiorentino', 'Hotel Santa Chiara', 'Borgo Palace Hotel', 'Albergo Ester', 'Bramante Hotel & Spa', 'Castello della Pieve', "Residenza d'epoca San Girolamo Casa e Vacanza Location per Eventi Frontino", 'Castello della Pieve', 'Agriturismo Montefiorentino', 'Country House Chiciabocca']
# ['Q944+HJ Montefiorentino, Province of Pesaro and Urbino, Italy', "MC86+59 Sant'Angelo in Vado, Province of Pesaro and Urbino, Italy", 'H4CG+6G Sansepolcro, Province of Arezzo, Italy', 'PCF6+92 Piandimeleto, Province of Pesaro and Urbino, Italy', 'MGF8+F6 Urbania, Province of Pesaro and Urbino, Italy', 'M867+X2 Mercatello sul Metauro, Province of Pesaro and Urbino, Italy', 'Q99G+JM Frontino, Province of Pesaro and Urbino, Italy', 'M867+X2 Mercatello sul Metauro, Province of Pesaro and Urbino, Italy', 'Q944+HJ Montefiorentino, Province of Pesaro and Urbino, Italy', 'GFHF+W8 Apecchio, Province of Pesaro and Urbino, Italy']
# ...

# %%
rcount = 0
names = []
for i in h_name:
    hotel_pinn = [{
        "name": h_name
        , "Zip, City, Country" : h_city
        , "location" : h_loc
    }]
    rcount += 1
pprint(hotel_pinn)
# Out:
# [{'Zip, City, Country': ['Q944+HJ Montefiorentino, Province of Pesaro and '
#                          'Urbino, Italy',
#                          "MC86+59 Sant'Angelo in Vado, Province of Pesaro and "
#                          'Urbino, Italy',
#                          'H4CG+6G Sansepolcro, Province of Arezzo, Italy',
#                          'PCF6+92 Piandimeleto, Province of Pesaro and Urbino, '
#                          'Italy',
#                          'MGF8+F6 Urbania, Province of Pesaro and Urbino, '
#                          'Italy',
#                          'M867+X2 Mercatello sul Metauro, Province of Pesaro '
#                          'and Urbino, Italy',
#                          'Q99G+JM Frontino, Province of Pesaro and Urbino, '
#                          'Italy',
#                          'M867+X2 Mercatello sul Metauro, Province of Pesaro '
#                          'and Urbino, Italy',
# ...

# %%
h_dict = [{
    "Name" : 'Agriturismo Montefiorentino', "location" : (43.756466, 12.356572), "City" : "Montefiorentino", "Country" : "Italy",
    "Name" : 'Hotel Santa Chiara', "location" : (43.665377, 12.410948), "City" : "Sant'Angelo in Vado", "Country" : "Italy",
    "Name" : 'Borgo Palace Hotel', "location" : (43.5706041, 12.1262724), "City" : "Sansepolcro", "Country" : "Italy",
    "Name" : 'Albergo Ester', "location" : (43.7234955, 12.4100037), "City" : "Piandimeleto", "Country" : "Italy",
    "Name" : 'Bramante Hotel & Spa', "location" : (43.673728, 12.515506), "City" : "Urbania", "Country" : "Italy",
    "Name" : 'Castello della Pieve', "location" : (43.6623854, 12.3125405), "City" : "Mercatello sul Metauro", "Country" : "Italy",
    "Name" : "Residenza d'epoca San Girolamo Casa e Vacanza Location per Eventi", "location" : (43.6623854, 12.3125405), \
    "City" : "Frontino", "Country" : "Itay",
    "Name" : 'Frontino', "location" : (43.7690541, 12.3766342), "City" : "Frontino", "Country" : "Italy",
    "Name" : 'Country House Chiciabocc', "location" : (43.5298305, 12.4732511), "City" : "Apecchio", "Country" : "Italy",
}]
h_locations = [h['location'] for h in h_dict]
info_box_template = """
<dl>
<dt>Name</dt><dd>{Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
h_info = [info_box_template.format(**h) for h in h_dict]

# %%
marker_layer1 = gmaps.marker_layer(h_locations, info_box_content = h_info)

# %%
fig.add_layer(marker_layer1)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
