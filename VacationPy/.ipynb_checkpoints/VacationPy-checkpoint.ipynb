# %%
import gmaps
from config import gkey
gmaps.configure(api_key=gkey)
from config import api_key
import requests
import json
import pandas as pd

# %%
city_id = []
from csv import reader
with open("log.csv", 'r', encoding='UTF-8') as reading_object:
    csv_reader = reader(reading_object)
    next(csv_reader)
    for i in csv_reader:
        city_id.append(i[2])

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
response_list = []
unit = 'Imperial'
for x in city_id:
    base_url = url + "id=" + str(x) + "&appid=" + api_key + "&units=" + unit
    response = requests.get(base_url).json()
    response_list.append(response)

# %%
response_list
# Out:
# [{'coord': {'lon': -67.8, 'lat': -2.87},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 73.9,
#    'feels_like': 81.72,
#    'temp_min': 73.9,
#    'temp_max': 73.9,
#    'pressure': 1013,
#    'humidity': 93,
#    'sea_level': 1013,
#    'grnd_level': 1007},
#   'wind': {'speed': 1.3, 'deg': 99},
#   'clouds': {'all': 33},
#   'dt': 1592793787,
#   'sys': {'country': 'BR', 'sunrise': 1592735665, 'sunset': 1592778702},
#   'timezone': -14400,
#   'id': 3661894,
#   'name': 'Tonantins',
#   'cod': 200},
#  {'coord': {'lon': -67.94, 'lat': -3.1},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 73.8,
#    'feels_like': 81.99,
#    'temp_min': 73.8,
#    'temp_max': 73.8,
#    'pressure': 1014,
#    'humidity': 95,
#    'sea_level': 1014,
#    'grnd_level': 1006},
#   'wind': {'speed': 1.12, 'deg': 101},
#   'clouds': {'all': 39},
#   'dt': 1592793787,
#   'sys': {'country': 'BR', 'sunrise': 1592735723, 'sunset': 1592778712},
#   'timezone': -14400,
#   'id': 3662395,
#   'name': 'Santo Antônio do Içá',
#   'cod': 200},
#  {'coord': {'lon': -56.5, 'lat': -24.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 68.85,
#    'feels_like': 69.04,
#    'temp_min': 68.85,
#    'temp_max': 68.85,
#    'pressure': 1016,
#    'humidity': 70,
#    'sea_level': 1016,
#    'grnd_level': 995},
#   'wind': {'speed': 4.59, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'country': 'PY', 'sunrise': 1592735332, 'sunset': 1592773611},
#   'timezone': -14400,
#   'id': 3437027,
#   'name': 'Departamento de San Pedro',
#   'cod': 200},
#  {'coord': {'lon': -55.5, 'lat': -24.08},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.6,
#    'feels_like': 69.48,
#    'temp_min': 69.6,
#    'temp_max': 69.6,
#    'pressure': 1017,
#    'humidity': 66,
#    'sea_level': 1017,
#    'grnd_level': 998},
#   'wind': {'speed': 4.59, 'deg': 63},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'country': 'PY', 'sunrise': 1592735071, 'sunset': 1592773392},
#   'timezone': -14400,
#   'id': 3436616,
#   'name': 'Ygatimi',
#   'cod': 200},
#  {'coord': {'lon': 2.83, 'lat': 43.08},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.17,
#    'feels_like': 66.81,
#    'temp_min': 71.01,
#    'temp_max': 71.6,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592798976,
#    'sunset': 1592854308},
#   'timezone': 7200,
#   'id': 2990918,
#   'name': 'Arrondissement de Narbonne',
#   'cod': 200},
#  {'coord': {'lon': 2.9, 'lat': 42.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.37,
#    'feels_like': 68.38,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799043,
#    'sunset': 1592854208},
#   'timezone': 7200,
#   'id': 6440996,
#   'name': 'Perpignan',
#   'cod': 200},
#  {'coord': {'lon': 2.92, 'lat': 11.33},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 80.22,
#    'feels_like': 82.83,
#    'temp_min': 80.22,
#    'temp_max': 80.22,
#    'pressure': 1010,
#    'humidity': 71,
#    'sea_level': 1010,
#    'grnd_level': 985},
#   'wind': {'speed': 8.86, 'deg': 200},
#   'clouds': {'all': 97},
#   'dt': 1592793788,
#   'sys': {'country': 'BJ', 'sunrise': 1592803603, 'sunset': 1592849639},
#   'timezone': 3600,
#   'id': 2597271,
#   'name': 'Alibori Department',
#   'cod': 200},
#  {'coord': {'lon': 2.94, 'lat': 11.13},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 78.35,
#    'feels_like': 81.64,
#    'temp_min': 78.35,
#    'temp_max': 78.35,
#    'pressure': 1010,
#    'humidity': 77,
#    'sea_level': 1010,
#    'grnd_level': 976},
#   'wind': {'speed': 8.19, 'deg': 202},
#   'clouds': {'all': 97},
#   'dt': 1592793744,
#   'sys': {'country': 'BJ', 'sunrise': 1592803620, 'sunset': 1592849612},
#   'timezone': 3600,
#   'id': 2393693,
#   'name': 'Kandi',
#   'cod': 200},
#  {'coord': {'lon': 2.75, 'lat': 42.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.28,
#    'feels_like': 68.27,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799068,
#    'sunset': 1592854255},
#   'timezone': 7200,
#   'id': 2987913,
#   'name': 'Arrondissement de Perpignan',
#   'cod': 200},
#  {'coord': {'lon': 3.49, 'lat': 34.9},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 67.82,
#    'feels_like': 62.73,
#    'temp_min': 67.82,
#    'temp_max': 67.82,
#    'pressure': 1020,
#    'humidity': 34,
#    'sea_level': 1020,
#    'grnd_level': 899},
#   'wind': {'speed': 4.59, 'deg': 23},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'country': 'DZ', 'sunrise': 1592800381, 'sunset': 1592852587},
#   'timezone': 3600,
#   'id': 2500904,
#   'name': 'Dar Chioukh',
#   'cod': 200},
#  {'coord': {'lon': 2.79, 'lat': 34.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 67.51,
#    'feels_like': 62.37,
#    'temp_min': 67.51,
#    'temp_max': 67.51,
#    'pressure': 1020,
#    'humidity': 36,
#    'sea_level': 1020,
#    'grnd_level': 893},
#   'wind': {'speed': 5.06, 'deg': 43},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'country': 'DZ', 'sunrise': 1592800596, 'sunset': 1592852708},
#   'timezone': 3600,
#   'id': 2501767,
#   'name': 'Charef',
#   'cod': 200},
#  {'coord': {'lon': 2.91, 'lat': 35.45},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.13,
#    'feels_like': 68.81,
#    'temp_min': 71.13,
#    'temp_max': 71.13,
#    'pressure': 1020,
#    'humidity': 38,
#    'sea_level': 1020,
#    'grnd_level': 943},
#   'wind': {'speed': 1.74, 'deg': 20},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'country': 'DZ', 'sunrise': 1592800428, 'sunset': 1592852818},
#   'timezone': 3600,
#   'id': 2507972,
#   'name': 'Aïn Oussera',
#   'cod': 200},
#  {'coord': {'lon': 3.25, 'lat': 43.35},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.91,
#    'feels_like': 65.16,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793788,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798816,
#    'sunset': 1592854267},
#   'timezone': 7200,
#   'id': 6455063,
#   'name': 'Béziers',
#   'cod': 200},
#  {'coord': {'lon': 3.47, 'lat': 43.32},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.35,
#    'feels_like': 64.44,
#    'temp_min': 69.01,
#    'temp_max': 69.8,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798770,
#    'sunset': 1592854208},
#   'timezone': 7200,
#   'id': 6424473,
#   'name': 'Agde',
#   'cod': 200},
#  {'coord': {'lon': 2.82, 'lat': 42.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 68.34,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799080,
#    'sunset': 1592854210},
#   'timezone': 7200,
#   'id': 6441052,
#   'name': 'Trouillas',
#   'cod': 200},
#  {'coord': {'lon': 2.77, 'lat': 42.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.3,
#    'feels_like': 68.29,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799074,
#    'sunset': 1592854239},
#   'timezone': 7200,
#   'id': 6440999,
#   'name': 'Pézilla-la-Rivière',
#   'cod': 200},
#  {'coord': {'lon': 3, 'lat': 43.18},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.7,
#    'feels_like': 66.18,
#    'temp_min': 69.8,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798914,
#    'sunset': 1592854290},
#   'timezone': 7200,
#   'id': 6453642,
#   'name': 'Narbonne',
#   'cod': 200},
#  {'coord': {'lon': 3, 'lat': 43.18},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.7,
#    'feels_like': 66.18,
#    'temp_min': 69.8,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798914,
#    'sunset': 1592854290},
#   'timezone': 7200,
#   'id': 2990919,
#   'name': 'Narbonne',
#   'cod': 200},
#  {'coord': {'lon': 2.81, 'lat': 42.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 68.34,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799084,
#    'sunset': 1592854210},
#   'timezone': 7200,
#   'id': 2971568,
#   'name': 'Trouillas',
#   'cod': 200},
#  {'coord': {'lon': 3.05, 'lat': 43.02},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.19,
#    'feels_like': 66.83,
#    'temp_min': 71.01,
#    'temp_max': 71.6,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592798937,
#    'sunset': 1592854242},
#   'timezone': 7200,
#   'id': 6426776,
#   'name': 'Port-la-Nouvelle',
#   'cod': 200},
#  {'coord': {'lon': 2.73, 'lat': 43.15},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 70.25,
#    'feels_like': 68.05,
#    'temp_min': 68,
#    'temp_max': 71.01,
#    'pressure': 1025,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6513,
#    'country': 'FR',
#    'sunrise': 1592798985,
#    'sunset': 1592854348},
#   'timezone': 7200,
#   'id': 6614944,
#   'name': 'Ferrals-les-Corbières',
#   'cod': 200},
#  {'coord': {'lon': 2.73, 'lat': 43.15},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 70.25,
#    'feels_like': 68.05,
#    'temp_min': 68,
#    'temp_max': 71.01,
#    'pressure': 1025,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6513,
#    'country': 'FR',
#    'sunrise': 1592798985,
#    'sunset': 1592854348},
#   'timezone': 7200,
#   'id': 3018671,
#   'name': 'Ferrals-les-Corbières',
#   'cod': 200},
#  {'coord': {'lon': 2.6, 'lat': 43.18},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 70.11,
#    'feels_like': 67.86,
#    'temp_min': 68,
#    'temp_max': 71.01,
#    'pressure': 1025,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6513,
#    'country': 'FR',
#    'sunrise': 1592799010,
#    'sunset': 1592854386},
#   'timezone': 7200,
#   'id': 6426657,
#   'name': 'Douzens',
#   'cod': 200},
#  {'coord': {'lon': 2.6, 'lat': 43.18},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 70.11,
#    'feels_like': 67.86,
#    'temp_min': 68,
#    'temp_max': 71.01,
#    'pressure': 1025,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6513,
#    'country': 'FR',
#    'sunrise': 1592799010,
#    'sunset': 1592854386},
#   'timezone': 7200,
#   'id': 3020875,
#   'name': 'Douzens',
#   'cod': 200},
#  {'coord': {'lon': 3.26, 'lat': 34.67},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 67.87,
#    'feels_like': 61.95,
#    'temp_min': 67.87,
#    'temp_max': 67.87,
#    'pressure': 1020,
#    'humidity': 34,
#    'sea_level': 1020,
#    'grnd_level': 895},
#   'wind': {'speed': 6.06, 'deg': 22},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'country': 'DZ', 'sunrise': 1592800475, 'sunset': 1592852604},
#   'timezone': 3600,
#   'id': 2500017,
#   'name': 'Djelfa',
#   'cod': 200},
#  {'coord': {'lon': 2.9, 'lat': 42.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.37,
#    'feels_like': 68.38,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793789,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799043,
#    'sunset': 1592854208},
#   'timezone': 7200,
#   'id': 2987914,
#   'name': 'Perpignan',
#   'cod': 200},
#  {'coord': {'lon': 2.93, 'lat': 42.68},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.39,
#    'feels_like': 68.4,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799040,
#    'sunset': 1592854197},
#   'timezone': 7200,
#   'id': 6450510,
#   'name': 'Cabestany',
#   'cod': 200},
#  {'coord': {'lon': 2.94, 'lat': 42.68},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.37,
#    'feels_like': 68.38,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799038,
#    'sunset': 1592854194},
#   'timezone': 7200,
#   'id': 3029302,
#   'name': 'Cabestany',
#   'cod': 200},
#  {'coord': {'lon': 2.62, 'lat': 42.67},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.32,
#    'feels_like': 68.31,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 1},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799117,
#    'sunset': 1592854269},
#   'timezone': 7200,
#   'id': 6450557,
#   'name': 'Ille-sur-Têt',
#   'cod': 200},
#  {'coord': {'lon': 2.62, 'lat': 42.67},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.32,
#    'feels_like': 68.31,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 1},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799117,
#    'sunset': 1592854269},
#   'timezone': 7200,
#   'id': 3012848,
#   'name': 'Ille-sur-Têt',
#   'cod': 200},
#  {'coord': {'lon': 2.77, 'lat': 43.2},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 70.21,
#    'feels_like': 68.02,
#    'temp_min': 68,
#    'temp_max': 71.01,
#    'pressure': 1025,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6513,
#    'country': 'FR',
#    'sunrise': 1592798964,
#    'sunset': 1592854349},
#   'timezone': 7200,
#   'id': 6426723,
#   'name': 'Lézignan-Corbières',
#   'cod': 200},
#  {'coord': {'lon': 2.76, 'lat': 43.2},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 70.21,
#    'feels_like': 68.02,
#    'temp_min': 68,
#    'temp_max': 71.01,
#    'pressure': 1025,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6513,
#    'country': 'FR',
#    'sunrise': 1592798967,
#    'sunset': 1592854352},
#   'timezone': 7200,
#   'id': 2998644,
#   'name': 'Lézignan-Corbières',
#   'cod': 200},
#  {'coord': {'lon': 3, 'lat': 42.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.88,
#    'feels_like': 69.04,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799036,
#    'sunset': 1592854167},
#   'timezone': 7200,
#   'id': 6454541,
#   'name': 'Saint-Cyprien',
#   'cod': 200},
#  {'coord': {'lon': 3, 'lat': 42.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.88,
#    'feels_like': 69.04,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799036,
#    'sunset': 1592854167},
#   'timezone': 7200,
#   'id': 2980984,
#   'name': 'Saint-Cyprien',
#   'cod': 200},
#  {'coord': {'lon': 2.7, 'lat': 42.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.28,
#    'feels_like': 68.27,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 1},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799076,
#    'sunset': 1592854271},
#   'timezone': 7200,
#   'id': 6450543,
#   'name': 'Estagel',
#   'cod': 200},
#  {'coord': {'lon': 2.7, 'lat': 42.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.28,
#    'feels_like': 68.27,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 1},
#   'dt': 1592793790,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799076,
#    'sunset': 1592854271},
#   'timezone': 7200,
#   'id': 3019584,
#   'name': 'Estagel',
#   'cod': 200},
#  {'coord': {'lon': 3.03, 'lat': 35.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.03,
#    'feels_like': 65.55,
#    'temp_min': 69.03,
#    'temp_max': 69.03,
#    'pressure': 1020,
#    'humidity': 36,
#    'sea_level': 1020,
#    'grnd_level': 921},
#   'wind': {'speed': 2.55, 'deg': 78},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'country': 'DZ', 'sunrise': 1592800463, 'sunset': 1592852726},
#   'timezone': 3600,
#   'id': 2494073,
#   'name': 'Hassi Bahbah',
#   'cod': 200},
#  {'coord': {'lon': 2.93, 'lat': 11.15},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 78.73,
#    'feels_like': 81.95,
#    'temp_min': 78.73,
#    'temp_max': 78.73,
#    'pressure': 1010,
#    'humidity': 76,
#    'sea_level': 1010,
#    'grnd_level': 979},
#   'wind': {'speed': 8.3, 'deg': 202},
#   'clouds': {'all': 98},
#   'dt': 1592793791,
#   'sys': {'country': 'BJ', 'sunrise': 1592803620, 'sunset': 1592849617},
#   'timezone': 3600,
#   'id': 2393923,
#   'name': 'Guida',
#   'cod': 200},
#  {'coord': {'lon': 3.33, 'lat': 43.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.87,
#    'feels_like': 65.1,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798808,
#    'sunset': 1592854237},
#   'timezone': 7200,
#   'id': 6432591,
#   'name': 'Portiragnes',
#   'cod': 200},
#  {'coord': {'lon': 3.33, 'lat': 43.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.87,
#    'feels_like': 65.1,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798808,
#    'sunset': 1592854237},
#   'timezone': 7200,
#   'id': 2985972,
#   'name': 'Portiragnes',
#   'cod': 200},
#  {'coord': {'lon': 2.85, 'lat': 42.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.25,
#    'feels_like': 68.22,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799044,
#    'sunset': 1592854231},
#   'timezone': 7200,
#   'id': 6440997,
#   'name': 'Peyrestortes',
#   'cod': 200},
#  {'coord': {'lon': 2.85, 'lat': 42.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.25,
#    'feels_like': 68.22,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799044,
#    'sunset': 1592854231},
#   'timezone': 7200,
#   'id': 2987500,
#   'name': 'Peyrestortes',
#   'cod': 200},
#  {'coord': {'lon': 3.22, 'lat': 43.35},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.93,
#    'feels_like': 65.17,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798823,
#    'sunset': 1592854275},
#   'timezone': 7200,
#   'id': 3032833,
#   'name': 'Béziers',
#   'cod': 200},
#  {'coord': {'lon': 3.48, 'lat': 43.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.33,
#    'feels_like': 64.4,
#    'temp_min': 69.01,
#    'temp_max': 69.8,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798769,
#    'sunset': 1592854203},
#   'timezone': 7200,
#   'id': 3038638,
#   'name': 'Agde',
#   'cod': 200},
#  {'coord': {'lon': 2.53, 'lat': 42.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 64.72,
#    'feels_like': 58.66,
#    'temp_min': 50,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 2},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799143,
#    'sunset': 1592854286},
#   'timezone': 7200,
#   'id': 6441063,
#   'name': 'Vinça',
#   'cod': 200},
#  {'coord': {'lon': 2.53, 'lat': 42.64},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 64.69,
#    'feels_like': 58.6,
#    'temp_min': 50,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 2},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799145,
#    'sunset': 1592854284},
#   'timezone': 7200,
#   'id': 2968062,
#   'name': 'Vinça',
#   'cod': 200},
#  {'coord': {'lon': 3.07, 'lat': 43.2},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.66,
#    'feels_like': 66.15,
#    'temp_min': 69.8,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798892,
#    'sunset': 1592854277},
#   'timezone': 7200,
#   'id': 6426926,
#   'name': 'Vinassan',
#   'cod': 200},
#  {'coord': {'lon': 3.07, 'lat': 43.2},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.66,
#    'feels_like': 66.15,
#    'temp_min': 69.8,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793791,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798892,
#    'sunset': 1592854277},
#   'timezone': 7200,
#   'id': 2968066,
#   'name': 'Vinassan',
#   'cod': 200},
#  {'coord': {'lon': 3.27, 'lat': 43.32},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.91,
#    'feels_like': 65.16,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798818,
#    'sunset': 1592854256},
#   'timezone': 7200,
#   'id': 6432687,
#   'name': 'Villeneuve-lès-Béziers',
#   'cod': 200},
#  {'coord': {'lon': 3.28, 'lat': 43.32},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.89,
#    'feels_like': 65.14,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798815,
#    'sunset': 1592854254},
#   'timezone': 7200,
#   'id': 2968544,
#   'name': 'Villeneuve les beziers',
#   'cod': 200},
#  {'coord': {'lon': 2.8, 'lat': 42.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.3,
#    'feels_like': 68.29,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799067,
#    'sunset': 1592854232},
#   'timezone': 7200,
#   'id': 6441062,
#   'name': 'Villeneuve-la-Rivière',
#   'cod': 200},
#  {'coord': {'lon': 2.8, 'lat': 42.69},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.3,
#    'feels_like': 68.29,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799069,
#    'sunset': 1592854230},
#   'timezone': 7200,
#   'id': 2968549,
#   'name': 'Villeneuve-la-Rivière',
#   'cod': 200},
#  {'coord': {'lon': 2.92, 'lat': 42.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.37,
#    'feels_like': 68.38,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793557,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799053,
#    'sunset': 1592854188},
#   'timezone': 7200,
#   'id': 6441061,
#   'name': 'Villeneuve-de-la-Raho',
#   'cod': 200},
#  {'coord': {'lon': 2.92, 'lat': 42.64},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.37,
#    'feels_like': 68.38,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799051,
#    'sunset': 1592854190},
#   'timezone': 7200,
#   'id': 2968571,
#   'name': 'Villeneuve-de-la-Raho',
#   'cod': 200},
#  {'coord': {'lon': 2.83, 'lat': 42.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 68.34,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799086,
#    'sunset': 1592854199},
#   'timezone': 7200,
#   'id': 6441060,
#   'name': 'Villemolaque',
#   'cod': 200},
#  {'coord': {'lon': 2.84, 'lat': 42.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.36,
#    'feels_like': 68.36,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799081,
#    'sunset': 1592854199},
#   'timezone': 7200,
#   'id': 2968654,
#   'name': 'Villemolaque',
#   'cod': 200},
#  {'coord': {'lon': 2.9, 'lat': 42.52},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.9,
#    'feels_like': 69.06,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799082,
#    'sunset': 1592854169},
#   'timezone': 7200,
#   'id': 6614551,
#   'name': 'Villelongue-dels-Monts',
#   'cod': 200},
#  {'coord': {'lon': 2.9, 'lat': 42.53},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.9,
#    'feels_like': 69.06,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799080,
#    'sunset': 1592854171},
#   'timezone': 7200,
#   'id': 2968690,
#   'name': 'Vilallonga dels Monts',
#   'cod': 200},
#  {'coord': {'lon': 2.98, 'lat': 42.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 68.34,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799017,
#    'sunset': 1592854195},
#   'timezone': 7200,
#   'id': 6441059,
#   'name': 'Villelongue-de-la-Salanque',
#   'cod': 200},
#  {'coord': {'lon': 2.98, 'lat': 42.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 68.34,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793792,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799017,
#    'sunset': 1592854195},
#   'timezone': 7200,
#   'id': 2968691,
#   'name': 'Villelongue-de-la-Salanque',
#   'cod': 200},
#  {'coord': {'lon': 3.42, 'lat': 43.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 65.01,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798784,
#    'sunset': 1592854218},
#   'timezone': 7200,
#   'id': 6432684,
#   'name': 'Vias',
#   'cod': 200},
#  {'coord': {'lon': 3.42, 'lat': 43.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 65.01,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798784,
#    'sunset': 1592854218},
#   'timezone': 7200,
#   'id': 2969421,
#   'name': 'Vias',
#   'cod': 200},
#  {'coord': {'lon': 3.22, 'lat': 43.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.94,
#    'feels_like': 65.21,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798841,
#    'sunset': 1592854257},
#   'timezone': 7200,
#   'id': 6454040,
#   'name': 'Vendres',
#   'cod': 200},
#  {'coord': {'lon': 3.22, 'lat': 43.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.94,
#    'feels_like': 65.21,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798841,
#    'sunset': 1592854257},
#   'timezone': 7200,
#   'id': 2970104,
#   'name': 'Vendres',
#   'cod': 200},
#  {'coord': {'lon': 3.37, 'lat': 43.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.91,
#    'feels_like': 65.16,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798771,
#    'sunset': 1592854254},
#   'timezone': 7200,
#   'id': 6432678,
#   'name': 'Valros',
#   'cod': 200},
#  {'coord': {'lon': 3.37, 'lat': 43.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.91,
#    'feels_like': 65.16,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798771,
#    'sunset': 1592854254},
#   'timezone': 7200,
#   'id': 2970837,
#   'name': 'Valros',
#   'cod': 200},
#  {'coord': {'lon': 3.28, 'lat': 43.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.91,
#    'feels_like': 65.16,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798831,
#    'sunset': 1592854238},
#   'timezone': 7200,
#   'id': 6432677,
#   'name': 'Valras-Plage',
#   'cod': 200},
#  {'coord': {'lon': 3.29, 'lat': 43.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.91,
#    'feels_like': 65.16,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798828,
#    'sunset': 1592854236},
#   'timezone': 7200,
#   'id': 2970839,
#   'name': 'Valras-Plage',
#   'cod': 200},
#  {'coord': {'lon': 3.38, 'lat': 43.45},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.4,
#    'feels_like': 64.51,
#    'temp_min': 69.01,
#    'temp_max': 69.8,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798762,
#    'sunset': 1592854259},
#   'timezone': 7200,
#   'id': 6432669,
#   'name': 'Tourbes',
#   'cod': 200},
#  {'coord': {'lon': 3.38, 'lat': 43.45},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.4,
#    'feels_like': 64.51,
#    'temp_min': 69.01,
#    'temp_max': 69.8,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798762,
#    'sunset': 1592854259},
#   'timezone': 7200,
#   'id': 2972288,
#   'name': 'Tourbes',
#   'cod': 200},
#  {'coord': {'lon': 2.83, 'lat': 42.67},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 68.34,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799066,
#    'sunset': 1592854218},
#   'timezone': 7200,
#   'id': 6441048,
#   'name': 'Toulouges',
#   'cod': 200},
#  {'coord': {'lon': 2.83, 'lat': 42.67},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 68.34,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793793,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799066,
#    'sunset': 1592854218},
#   'timezone': 7200,
#   'id': 2972317,
#   'name': 'Toulouges',
#   'cod': 200},
#  {'coord': {'lon': 2.98, 'lat': 42.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.32,
#    'feels_like': 68.31,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799013,
#    'sunset': 1592854200},
#   'timezone': 7200,
#   'id': 6441047,
#   'name': 'Torreilles',
#   'cod': 200},
#  {'coord': {'lon': 2.99, 'lat': 42.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.32,
#    'feels_like': 68.31,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799011,
#    'sunset': 1592854197},
#   'timezone': 7200,
#   'id': 2972412,
#   'name': 'Torreilles',
#   'cod': 200},
#  {'coord': {'lon': 2.75, 'lat': 42.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.32,
#    'feels_like': 68.31,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799094,
#    'sunset': 1592854229},
#   'timezone': 7200,
#   'id': 6441045,
#   'name': 'Thuir',
#   'cod': 200},
#  {'coord': {'lon': 2.75, 'lat': 42.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.32,
#    'feels_like': 68.31,
#    'temp_min': 71.6,
#    'temp_max': 73,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799094,
#    'sunset': 1592854229},
#   'timezone': 7200,
#   'id': 2972665,
#   'name': 'Thuir',
#   'cod': 200},
#  {'coord': {'lon': 3.17, 'lat': 43.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.94,
#    'feels_like': 65.21,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798819,
#    'sunset': 1592854302},
#   'timezone': 7200,
#   'id': 6614352,
#   'name': 'Thézan-lès-Béziers',
#   'cod': 200},
#  {'coord': {'lon': 3.17, 'lat': 43.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.94,
#    'feels_like': 65.21,
#    'temp_min': 69.01,
#    'temp_max': 71.01,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798819,
#    'sunset': 1592854302},
#   'timezone': 7200,
#   'id': 2972904,
#   'name': 'Thézan-lès-Béziers',
#   'cod': 200},
#  {'coord': {'lon': 2.95, 'lat': 42.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.84,
#    'feels_like': 68.99,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799046,
#    'sunset': 1592854181},
#   'timezone': 7200,
#   'id': 6441044,
#   'name': 'Théza',
#   'cod': 200},
#  {'coord': {'lon': 2.95, 'lat': 42.64},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.84,
#    'feels_like': 68.99,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799044,
#    'sunset': 1592854183},
#   'timezone': 7200,
#   'id': 2972908,
#   'name': 'Théza',
#   'cod': 200},
#  {'coord': {'lon': 2.96, 'lat': 42.53},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.9,
#    'feels_like': 69.06,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799066,
#    'sunset': 1592854157},
#   'timezone': 7200,
#   'id': 6614578,
#   'name': 'Sorède',
#   'cod': 200},
#  {'coord': {'lon': 2.96, 'lat': 42.53},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.9,
#    'feels_like': 69.06,
#    'temp_min': 71.6,
#    'temp_max': 73.99,
#    'pressure': 1023,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1592793794,
#   'sys': {'type': 1,
#    'id': 6517,
#    'country': 'FR',
#    'sunrise': 1592799066,
#    'sunset': 1592854157},
# ...
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798374,
#    'sunset': 1592854138},
#   'timezone': 7200,
#   'id': 2977274,
#   'name': 'Saint-Quentin-la-Poterie',
#   'cod': 200},
#  {'coord': {'lon': 4.17, 'lat': 43.66},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.64,
#    'feels_like': 64.94,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793869,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798525,
#    'sunset': 1592854116},
#   'timezone': 7200,
#   'id': 2995456,
#   'name': 'Marsillargues',
#   'cod': 200},
#  {'coord': {'lon': 4.45, 'lat': 43.86},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.61,
#    'feels_like': 65.46,
#    'temp_min': 69.8,
#    'temp_max': 71.6,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793869,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798412,
#    'sunset': 1592854095},
#   'timezone': 7200,
#   'id': 2995782,
#   'name': 'Marguerittes',
#   'cod': 200},
#  {'coord': {'lon': 4.47, 'lat': 43.82},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.56,
#    'feels_like': 65.39,
#    'temp_min': 69.8,
#    'temp_max': 71.6,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793869,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798417,
#    'sunset': 1592854081},
#   'timezone': 7200,
#   'id': 2996236,
#   'name': 'Manduel',
#   'cod': 200},
#  {'coord': {'lon': 4.09, 'lat': 43.68},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.71,
#    'feels_like': 65.03,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793869,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798540,
#    'sunset': 1592854140},
#   'timezone': 7200,
#   'id': 2997113,
#   'name': 'Lunel-Viel',
#   'cod': 200},
#  {'coord': {'lon': 3.6, 'lat': 43.98},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 72.84,
#    'feels_like': 66.49,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793869,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798589,
#    'sunset': 1592854326},
#   'timezone': 7200,
#   'id': 2998811,
#   'name': 'Le Vigan',
#   'cod': 200},
#  {'coord': {'lon': 4.13, 'lat': 44.41},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 57.2,
#    'temp_min': 69.8,
#    'temp_max': 69.8,
#    'pressure': 1020,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 25.28, 'deg': 350},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6516,
#    'country': 'FR',
#    'sunrise': 1592798362,
#    'sunset': 1592854298},
#   'timezone': 7200,
#   'id': 2999391,
#   'name': 'Les Vans',
#   'cod': 200},
#  {'coord': {'lon': 4.04, 'lat': 44.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 64.42,
#    'temp_min': 69.8,
#    'temp_max': 69.8,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798430,
#    'sunset': 1592854273},
#   'timezone': 7200,
#   'id': 2999649,
#   'name': 'Les Salles-du-Gardon',
#   'cod': 200},
#  {'coord': {'lon': 3.81, 'lat': 43.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'feels_like': 67.21,
#    'temp_min': 73.4,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798596,
#    'sunset': 1592854219},
#   'timezone': 7200,
#   'id': 3000353,
#   'name': 'Les Matelles',
#   'cod': 200},
#  {'coord': {'lon': 4.17, 'lat': 44.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.05,
#    'feels_like': 64.74,
#    'temp_min': 69.8,
#    'temp_max': 71.6,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798395,
#    'sunset': 1592854247},
#   'timezone': 7200,
#   'id': 3000444,
#   'name': 'Les Mages',
#   'cod': 200},
#  {'coord': {'lon': 3.52, 'lat': 43.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.7,
#    'feels_like': 66.81,
#    'temp_min': 69.01,
#    'temp_max': 73.4,
#    'pressure': 1022,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6519,
#    'country': 'FR',
#    'sunrise': 1592798697,
#    'sunset': 1592854257},
#   'timezone': 7200,
#   'id': 3002541,
#   'name': 'Le Pouget',
#   'cod': 200},
#  {'coord': {'lon': 4.14, 'lat': 43.54},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.73,
#    'feels_like': 65.05,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798559,
#    'sunset': 1592854096},
#   'timezone': 7200,
#   'id': 3003918,
#   'name': 'Le Grau-du-Roi',
#   'cod': 200},
#  {'coord': {'lon': 4.11, 'lat': 43.99},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.56,
#    'feels_like': 66.7,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798464,
#    'sunset': 1592854206},
#   'timezone': 7200,
#   'id': 3004346,
#   'name': 'Lédignan',
#   'cod': 200},
#  {'coord': {'lon': 3.94, 'lat': 43.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'feels_like': 67.21,
#    'temp_min': 73.4,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798583,
#    'sunset': 1592854169},
#   'timezone': 7200,
#   'id': 3004434,
#   'name': 'Le Crès',
#   'cod': 200},
#  {'coord': {'lon': 4.24, 'lat': 43.68},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.51,
#    'feels_like': 66.63,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798504,
#    'sunset': 1592854104},
#   'timezone': 7200,
#   'id': 3004891,
#   'name': 'Le Cailar',
#   'cod': 200},
#  {'coord': {'lon': 3.81, 'lat': 43.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'feels_like': 67.21,
#    'temp_min': 73.4,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798627,
#    'sunset': 1592854187},
#   'timezone': 7200,
#   'id': 3005632,
#   'name': 'Lavérune',
#   'cod': 200},
#  {'coord': {'lon': 4.07, 'lat': 44.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 64.42,
#    'temp_min': 69.8,
#    'temp_max': 69.8,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798423,
#    'sunset': 1592854266},
#   'timezone': 7200,
#   'id': 3005792,
#   'name': 'Laval-Pradel',
#   'cod': 200},
#  {'coord': {'lon': 3.85, 'lat': 44.05},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.65,
#    'feels_like': 64.96,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793870,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798513,
#    'sunset': 1592854282},
#   'timezone': 7200,
#   'id': 3006543,
#   'name': 'Lasalle',
#   'cod': 200},
#  {'coord': {'lon': 3.72, 'lat': 43.92},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.87,
#    'feels_like': 65.23,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798574,
#    'sunset': 1592854283},
#   'timezone': 7200,
#   'id': 3006711,
#   'name': 'Laroque',
#   'cod': 200},
#  {'coord': {'lon': 4.08, 'lat': 43.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.78,
#    'feels_like': 65.12,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798549,
#    'sunset': 1592854136},
#   'timezone': 7200,
#   'id': 3007541,
#   'name': 'Lansargues',
#   'cod': 200},
#  {'coord': {'lon': 4.25, 'lat': 43.8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.46,
#    'feels_like': 66.56,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798474,
#    'sunset': 1592854129},
#   'timezone': 7200,
#   'id': 3007715,
#   'name': 'Langlade',
#   'cod': 200},
#  {'coord': {'lon': 4.08, 'lat': 43.57},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.85,
#    'feels_like': 65.21,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798567,
#    'sunset': 1592854118},
#   'timezone': 7200,
#   'id': 3008981,
#   'name': 'La Grande-Motte',
#   'cod': 200},
#  {'coord': {'lon': 4.27, 'lat': 43.92},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 64.42,
#    'temp_min': 69.8,
#    'temp_max': 69.8,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798442,
#    'sunset': 1592854151},
#   'timezone': 7200,
#   'id': 3010634,
#   'name': 'La Calmette',
#   'cod': 200},
#  {'coord': {'lon': 4.22, 'lat': 44.47},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 57.2,
#    'temp_min': 69.8,
#    'temp_max': 69.8,
#    'pressure': 1020,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 25.28, 'deg': 350},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6516,
#    'country': 'FR',
#    'sunrise': 1592798327,
#    'sunset': 1592854291},
#   'timezone': 7200,
#   'id': 3011021,
#   'name': 'Lablachère',
#   'cod': 200},
#  {'coord': {'lon': 3.81, 'lat': 43.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'feels_like': 67.21,
#    'temp_min': 73.4,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798623,
#    'sunset': 1592854191},
#   'timezone': 7200,
#   'id': 3012004,
#   'name': 'Juvignac',
#   'cod': 200},
#  {'coord': {'lon': 4.24, 'lat': 44.48},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'feels_like': 57.2,
#    'temp_min': 69.8,
#    'temp_max': 69.8,
#    'pressure': 1020,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 25.28, 'deg': 350},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6516,
#    'country': 'FR',
#    'sunrise': 1592798319,
#    'sunset': 1592854288},
#   'timezone': 7200,
#   'id': 3012148,
#   'name': 'Joyeuse',
#   'cod': 200},
#  {'coord': {'lon': 3.91, 'lat': 43.66},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'feels_like': 67.21,
#    'temp_min': 73.4,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6518,
#    'country': 'FR',
#    'sunrise': 1592798588,
#    'sunset': 1592854179},
#   'timezone': 7200,
#   'id': 3012576,
#   'name': 'Jacou',
#   'cod': 200},
#  {'coord': {'lon': 4.17, 'lat': 43.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.58,
#    'feels_like': 66.72,
#    'temp_min': 69.8,
#    'temp_max': 73.4,
#    'pressure': 1020,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1592793871,
#   'sys': {'type': 1,
#    'id': 6599,
#    'country': 'FR',
#    'sunrise': 1592798512,
#    'sunset': 1592854130},
#   'timezone': 7200,
#   'id': 3015119,
#   'name': 'Gallargues-le-Montueux',
#   'cod': 200},
#  ...]

# %%
coord = []
hum = []
for x in response_list:
    coord.append((float(x['coord']['lon']), float(x['coord']['lat']) ) )
    hum.append(int(x['main']['humidity']) )

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
fig.add_layer(gmaps.heatmap_layer(coord, weights=hum))

# %%
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
best_weather = []
best_weather_coord = []
for x in response_list:
    if 80 >= float(x['main']['temp_max']) >= 70 and float(x['wind']['speed']) < 7 and float(x['main']['humidity']) <= 28 \
    and float(x['clouds']['all'])==0:
        best_weather.append(x['name'])
        best_weather_coord.append((float(x['coord']['lon']), float(x['coord']['lat'] ) ) )
print(best_weather)
print(best_weather_coord)
# Out:
# ['Naama', 'Naama', 'Mecheria']
# [(-0.32, 33.27), (-0.32, 33.27), (-0.28, 33.54)]
