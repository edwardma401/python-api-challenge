# %%
import gmaps
from config import gkey
gmaps.configure(api_key=gkey)
from config import api_key
import requests
import json
import pandas as pd
from pprint import pprint

# %%
city_id = []
from csv import reader
with open("log.csv", 'r', encoding='UTF-8') as reading_object:
    csv_reader = reader(reading_object)
    next(csv_reader)
    for i in csv_reader:
        city_id.append(i[2])

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
response_list = []
unit = 'Imperial'
for x in city_id:
    base_url = url + "id=" + str(x) + "&appid=" + api_key + "&units=" + unit
    response = requests.get(base_url).json()
    response_list.append(response)

# %%
coord = []
hum = []
for x in response_list:
    coord.append((float(x['coord']['lon']), float(x['coord']['lat']) ) )
    hum.append(int(x['main']['humidity']) )

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
fig.add_layer(gmaps.heatmap_layer(coord, weights=hum))

# %%
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
best_weather = []
best_weather_coord = []
for x in response_list:
    if 85 >= float(x['main']['temp_max']) >= 70 and float(x['wind']['speed']) < 5 and float(x['main']['humidity']) <= 40 \
    and float(x['clouds']['all'])==0:
        best_weather.append(x['name'])
        best_weather_coord.append(  x['coord']   ) 
print(best_weather)
print(best_weather_coord)
lat = best_weather_coord[0]['lat']
print(lat)
lon = best_weather_coord[0]['lon']
print(lon)
# Out:
# ['Locoquicha', 'Melouza', 'Gemeente Middelharnis', 'Melouza', 'Middelharnis', 'Dirksland', 'Cunene Province', 'Sankt Radegund bei Graz', 'Sankt Radegund bei Graz', 'Leutschach', 'Leutschach', 'Gemeente Middelharnis', 'Melouza', 'Middelharnis']
# [{'lon': 22.17, 'lat': -10.4}, {'lon': 4.19, 'lat': 35.98}, {'lon': 4.15, 'lat': 51.75}, {'lon': 4.19, 'lat': 35.98}, {'lon': 4.17, 'lat': 51.76}, {'lon': 4.1, 'lat': 51.75}, {'lon': 15.44, 'lat': -16.51}, {'lon': 15.48, 'lat': 47.18}, {'lon': 15.48, 'lat': 47.17}, {'lon': 15.47, 'lat': 46.67}, {'lon': 15.47, 'lat': 46.67}, {'lon': 4.15, 'lat': 51.75}, {'lon': 4.19, 'lat': 35.98}, {'lon': 4.17, 'lat': 51.76}]
# -10.4
# 22.17

# %%
counts = 0
hotel_data=[]
for x in best_weather_coord:
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
    "location": str(x['lat']) + "," + str(x['lon']),
#     "query": "Best Hotel",
    "keyword": "hotel",
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}
    response = requests.get(base_url, params=params).json()
    if response['results'] != []:
        hotel_data.append(response)

# %%
pprint(hotel_data)
# Out:
# [{'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7490935,
#                                          'lng': 4.103901899999999},
#                             'viewport': {'northeast': {'lat': 51.75046792989272,
#                                                        'lng': 4.105310929892721},
#                                          'southwest': {'lat': 51.74776827010728,
#                                                        'lng': 4.102611270107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#                'id': 'db836ecacea72f2e7225c772394dabe3e1fb20b4',
#                'name': 'De Snoeperij',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 4608,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/107687817201519942100">edith</a>'],
#                            'photo_reference': 'CmRaAAAAdoLdBSVsO-oaFdVEnamG6lNsy00jrpZofr7dxh9GINX-6mGrLP75bKV8-_grQwX7F7x0f0_JmbQoVE6lUrmCB8SLRvY0hb0oQX8ZeqPTon-QggyIS-mcclbp9Aap8wO_EhCxtKq03UhQpigVmZTP5OPgGhRz-PloIjsrahduZcKgHObj9_QenA',
#                            'width': 3456}],
#                'place_id': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'plus_code': {'compound_code': 'P4X3+JH Dirksland, Netherlands',
#                              'global_code': '9F36P4X3+JH'},
#                'rating': 4.4,
#                'reference': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'scope': 'GOOGLE',
#                'types': ['cafe',
#                          'lodging',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 77,
#                'vicinity': 'Straatdijk 2, Dirksland'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.76240929999999,
#                                          'lng': 4.144411},
#                             'viewport': {'northeast': {'lat': 51.76388062989272,
#                                                        'lng': 4.145470829892722},
#                                          'southwest': {'lat': 51.76118097010728,
#                                                        'lng': 4.142771170107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '36e1eafd5f39844f628fc8cd7d01468ce837e0a1',
#                'name': 'Sommelsdijk',
#                'photos': [{'height': 1884,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108895009111372736249">Josiane '
#                                                  'Vandenhautte</a>'],
#                            'photo_reference': 'CmRaAAAA_iTNDmRrY0TFwQDFu4NNk1BhBe8h_VFmUygf271dlv3Njvd1JmnEYX2Dr6siezAIGxurDwOcF6RyZ7oArMsMvrmdpQ0Z7u67otxoDIrRy-vT3UxRpLbA7Zn3PjRfvCifEhAer0mM2KWrti04pYFXeo4DGhQrAjwMJmJIpeiz3mCl7_IZwq7fgQ',
#                            'width': 1272}],
#                'place_id': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'plus_code': {'compound_code': 'Q46V+XQ Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q46V+XQ'},
#                'rating': 4.6,
#                'reference': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 12,
#                'vicinity': 'Prutweg 6, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.759176, 'lng': 4.165355},
#                             'viewport': {'northeast': {'lat': 51.76051227989272,
#                                                        'lng': 4.166822879892722},
#                                          'southwest': {'lat': 51.75781262010728,
#                                                        'lng': 4.164123220107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '8430829538aaa4b355a4c3f32c982c39932ccb26',
#                'name': 'De Oude Bank',
#                'photos': [{'height': 960,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/105173598034239957349">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAlGygfP0WcJlfvpLtH99g39kwhW8SXTCPn7kJvNZm8H2JtsUnOrI5i87HdbVLTKoK5xQlr0t-odA3oBq_dGOkM13A7qX2DeMey-CtZJ3gq_NSygSd18me_3-YAvIMC7-ZEhDhLEyLJWqysmOwkEWCBUd_GhTvSKVaBnQGshvxP6wfhffccpdOHQ',
#                            'width': 1440}],
#                'place_id': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'plus_code': {'compound_code': 'Q558+M4 Middelharnis, '
#                                               'Netherlands',
#                              'global_code': '9F36Q558+M4'},
#                'rating': 4.6,
#                'reference': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 15,
#                'vicinity': 'Voorstraat 33, Middelharnis'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7591432, 'lng': 4.1552058},
#                             'viewport': {'northeast': {'lat': 51.76051512989272,
#                                                        'lng': 4.156657779892721},
#                                          'southwest': {'lat': 51.75781547010728,
#                                                        'lng': 4.153958120107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '76a5e4f7a374f2666bcb6d53a4b66e614748c6be',
#                'name': 'bed & breakfast Kantje Levantje',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 918,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101156557871213563787">bed '
#                                                  '&amp; breakfast Kantje '
#                                                  'Levantje</a>'],
#                            'photo_reference': 'CmRaAAAA7uEcx_1oH_Bxx_oMwKpRBQFBcYJRsiBrbo6xGxSrh2lCJ-ElGn09OW2O5RIFLHMDxBxoPrY5OO2kAG73YgesbS8DSe2BFXtCOQkR4aiK4Y98_Zyt_bCUHB2ns8cP31BaEhCVJxTmhW_LZjpAmCTexi5YGhScz9btgkxH5U9wvB6CuRAiq-wr5A',
#                            'width': 1632}],
#                'place_id': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'plus_code': {'compound_code': 'Q554+M3 Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q554+M3'},
#                'rating': 4.6,
#                'reference': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'scope': 'GOOGLE',
#                'types': ['real_estate_agency',
#                          'travel_agency',
#                          'lodging',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 49,
#                'vicinity': 'Langeweg 23, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.70968000000001,
#                                          'lng': 4.078116},
#                             'viewport': {'northeast': {'lat': 51.71101127989272,
#                                                        'lng': 4.079462079892722},
#                                          'southwest': {'lat': 51.70831162010728,
#                                                        'lng': 4.076762420107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'c1a3c0d012ff614e38c61b53380f3bf53d4eb4b5',
#                'name': 'Peaceful Holiday Home in South Holland by the Lake',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 683,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/109563002916394204876">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAkMyxhdsB5yejzXLrAoy1yA7ho4lzle08lPO0wPZrmSayEjAO4Ga8dVIGlFgME6l1caTxBGyZ2m_B_Ug-lmdIP-mSlHUl24Ip0Q0twsbq2WGWyFmMcr_xPOAwDpy7vM2KEhA8GTZ9AyqT-2Bs95JIC17SGhSuZhSBIy_ykORLJk285KTU0993yw',
#                            'width': 1214}],
#                'place_id': 'ChIJbYhY7s1bxEcRK7kSpyJQJIw',
#                'plus_code': {'compound_code': 'P35H+V6 Herkingen, Netherlands',
#                              'global_code': '9F36P35H+V6'},
#                'rating': 4.5,
#                'reference': 'ChIJbYhY7s1bxEcRK7kSpyJQJIw',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 2,
#                'vicinity': 'Herkingsezeedijk 226, Herkingen'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7508875,
#                                          'lng': 4.097790499999999},
#                             'viewport': {'northeast': {'lat': 51.75215567989272,
#                                                        'lng': 4.099160479892721},
#                                          'southwest': {'lat': 51.74945602010728,
#                                                        'lng': 4.096460820107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'da24a88bd490a600632e2270929cc23a0aafcf33',
#                'name': 'Bed & Breakfast Groenewege',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3024,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/114478124704923928536">Ad '
#                                                  'Hoen</a>'],
#                            'photo_reference': 'CmRaAAAALqzDtPoPed1RoAjf6txQaxiaafJGHkNKvoPGaJiDZpxmiFs733qlCj1Ufytbm0Bs0FI8j1LHtIHzuLOhAdCbO8ecgU8FvTO3CnMq-LEsDes1cTmVs8VuDbr3p03LUMZ6EhBkj2a5SNa-rrg8McWXkbZyGhRu51HFKdltUYpd99MCu9Mkcdee2w',
#                            'width': 4032}],
#                'place_id': 'ChIJbRlnwfBaxEcRWdMmsQtZIyU',
#                'plus_code': {'compound_code': 'Q32X+94 Dirksland, Netherlands',
#                              'global_code': '9F36Q32X+94'},
#                'rating': 4.8,
#                'reference': 'ChIJbRlnwfBaxEcRWdMmsQtZIyU',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 12,
#                'vicinity': 'Boezemweg 62, Dirksland'}],
#   'status': 'OK'},
#  {'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7490935,
#                                          'lng': 4.103901899999999},
#                             'viewport': {'northeast': {'lat': 51.75046792989272,
#                                                        'lng': 4.105310929892721},
#                                          'southwest': {'lat': 51.74776827010728,
#                                                        'lng': 4.102611270107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#                'id': 'db836ecacea72f2e7225c772394dabe3e1fb20b4',
#                'name': 'De Snoeperij',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 4608,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/107687817201519942100">edith</a>'],
#                            'photo_reference': 'CmRaAAAAh-K5eLgkSUHUFH0eb0g-IMGVKVSeiL4PKFThGPFTuVPnxYdv18bL1K0QHZkFHQn2G-bz9XxHtHrGP-1DuVGEG5RmMwEHBotZS8C6jX0jE4lsQOr9tVpjwZ-vQ-hYfIrHEhAecIoGn9jVftdHfNkqWtVcGhRn4-UOvxUetbEH5lRYJHqxpUsOdg',
#                            'width': 3456}],
#                'place_id': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'plus_code': {'compound_code': 'P4X3+JH Dirksland, Netherlands',
#                              'global_code': '9F36P4X3+JH'},
#                'rating': 4.4,
#                'reference': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'scope': 'GOOGLE',
#                'types': ['cafe',
#                          'lodging',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 77,
#                'vicinity': 'Straatdijk 2, Dirksland'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.76240929999999,
#                                          'lng': 4.144411},
#                             'viewport': {'northeast': {'lat': 51.76388062989272,
#                                                        'lng': 4.145470829892722},
#                                          'southwest': {'lat': 51.76118097010728,
#                                                        'lng': 4.142771170107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '36e1eafd5f39844f628fc8cd7d01468ce837e0a1',
#                'name': 'Sommelsdijk',
#                'photos': [{'height': 1884,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108895009111372736249">Josiane '
#                                                  'Vandenhautte</a>'],
#                            'photo_reference': 'CmRaAAAARnsOeycjRlqnnujUmCbLFf4KHf-2RXT7fT5WwzyF_67P36-mfsI61D83Wg9vaoEA8wlyku74nTxYm-daw0CGksoUIq1HATKumN5FONtn8BHRzG5BhqcNrS1HtzW1k1ocEhDMhl4OUg3ItXHE0ejo-3TTGhSpJBqnaAn6UIya58ZCH6kd2HtyhA',
#                            'width': 1272}],
#                'place_id': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'plus_code': {'compound_code': 'Q46V+XQ Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q46V+XQ'},
#                'rating': 4.6,
#                'reference': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 12,
#                'vicinity': 'Prutweg 6, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7591432, 'lng': 4.1552058},
#                             'viewport': {'northeast': {'lat': 51.76051512989272,
#                                                        'lng': 4.156657779892721},
#                                          'southwest': {'lat': 51.75781547010728,
#                                                        'lng': 4.153958120107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '76a5e4f7a374f2666bcb6d53a4b66e614748c6be',
#                'name': 'bed & breakfast Kantje Levantje',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 918,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101156557871213563787">bed '
#                                                  '&amp; breakfast Kantje '
#                                                  'Levantje</a>'],
#                            'photo_reference': 'CmRaAAAAoJqV-FAfiTdSZ8PXcHuAgh3-n910XQ1szlvpiFvt2mYjFnOIgphTqJDDQwHUtmRrmnroqcpKEAkXYMMraPCgEiWfI4sHWN9U9cZ2khsY6kFPtuEqKkUiOM4flG3Quh4oEhDcnb6hdqxBPgPD1Htye3pJGhTyGuve-3rjzEfitjpkHd2no0592w',
#                            'width': 1632}],
#                'place_id': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'plus_code': {'compound_code': 'Q554+M3 Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q554+M3'},
#                'rating': 4.6,
#                'reference': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'scope': 'GOOGLE',
#                'types': ['real_estate_agency',
#                          'travel_agency',
#                          'lodging',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 49,
#                'vicinity': 'Langeweg 23, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.759176, 'lng': 4.165355},
#                             'viewport': {'northeast': {'lat': 51.76051227989272,
#                                                        'lng': 4.166822879892722},
#                                          'southwest': {'lat': 51.75781262010728,
#                                                        'lng': 4.164123220107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '8430829538aaa4b355a4c3f32c982c39932ccb26',
#                'name': 'De Oude Bank',
#                'photos': [{'height': 960,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/105173598034239957349">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAAuEbDKXS5DVRKAfPZmzifB107GSwpI2LNABKfKbS5MU4OvH0bvbMv7-pOhxFNRrRWguOsNmgpmDyWRBmPbl4NThZ8Jl6SNwuEtIlpZl-q8qHqmIZXMoMwPgGGdhdVPvWEhASFwUdUkt6vOQLgBBVdaq_GhSUBUoLF4ZeTFRazysIfWLzWEul3Q',
#                            'width': 1440}],
#                'place_id': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'plus_code': {'compound_code': 'Q558+M4 Middelharnis, '
#                                               'Netherlands',
#                              'global_code': '9F36Q558+M4'},
#                'rating': 4.6,
#                'reference': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 15,
#                'vicinity': 'Voorstraat 33, Middelharnis'}],
#   'status': 'OK'},
#  {'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7490935,
#                                          'lng': 4.103901899999999},
#                             'viewport': {'northeast': {'lat': 51.75046792989272,
#                                                        'lng': 4.105310929892721},
#                                          'southwest': {'lat': 51.74776827010728,
#                                                        'lng': 4.102611270107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#                'id': 'db836ecacea72f2e7225c772394dabe3e1fb20b4',
#                'name': 'De Snoeperij',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 4608,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/107687817201519942100">edith</a>'],
#                            'photo_reference': 'CmRaAAAAPoaA8MDMo_u9RVjeRNVvSvTFUhPFrw1MYCmiTyNdMKrJ2E3DNnVM1SoiPcwhOT5bT8YtroKNaYbKoGgNZ1INvXnci7nfkABt12N0fbEHDg2ipodBG6owEIuBfdqllSSaEhCZpBRguL1LTd7RPhB38g60GhTppLF_m4f23vO7884BtoN61CtBMw',
#                            'width': 3456}],
#                'place_id': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'plus_code': {'compound_code': 'P4X3+JH Dirksland, Netherlands',
#                              'global_code': '9F36P4X3+JH'},
#                'rating': 4.4,
#                'reference': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'scope': 'GOOGLE',
#                'types': ['cafe',
#                          'lodging',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 77,
#                'vicinity': 'Straatdijk 2, Dirksland'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.76240929999999,
#                                          'lng': 4.144411},
#                             'viewport': {'northeast': {'lat': 51.76388062989272,
#                                                        'lng': 4.145470829892722},
#                                          'southwest': {'lat': 51.76118097010728,
#                                                        'lng': 4.142771170107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '36e1eafd5f39844f628fc8cd7d01468ce837e0a1',
#                'name': 'Sommelsdijk',
#                'photos': [{'height': 1884,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108895009111372736249">Josiane '
#                                                  'Vandenhautte</a>'],
#                            'photo_reference': 'CmRaAAAAzB04ld2mjsZThI2uIU5aOhFWdFt6TkQHkYgMVanf78zpc6tazdIDNWICZgsAsPEXLw8wori1Mx7Mdrm0hkyt20WkRfiCG_HRLxV7c19EBnG51wwFkZ3dLQL5HG2TrNhhEhAwg1w05BGFyZePcyJC20shGhTz_g0LB99Nt5yX1H_70e2OLaIrPg',
#                            'width': 1272}],
#                'place_id': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'plus_code': {'compound_code': 'Q46V+XQ Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q46V+XQ'},
#                'rating': 4.6,
#                'reference': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 12,
#                'vicinity': 'Prutweg 6, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.759176, 'lng': 4.165355},
#                             'viewport': {'northeast': {'lat': 51.76051227989272,
#                                                        'lng': 4.166822879892722},
#                                          'southwest': {'lat': 51.75781262010728,
#                                                        'lng': 4.164123220107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '8430829538aaa4b355a4c3f32c982c39932ccb26',
#                'name': 'De Oude Bank',
#                'photos': [{'height': 960,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/105173598034239957349">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAg696wT-AHhR7a38xqCDcATMeo2gKt-bX2gqqdrNIdlQJtQcXKW8ZF1UNUQ0is6AzNvcO19xfGli-O6_PXNO5wz0uWMi6dvK3YCkUOuASzJIVB4cPRDxxdRXXEUetMOYuEhBcqGK4cjb3ys7A2NZvQZlHGhRpM68Uaft6wXLiimabhuU9juM-XA',
#                            'width': 1440}],
#                'place_id': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'plus_code': {'compound_code': 'Q558+M4 Middelharnis, '
#                                               'Netherlands',
#                              'global_code': '9F36Q558+M4'},
#                'rating': 4.6,
#                'reference': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 15,
#                'vicinity': 'Voorstraat 33, Middelharnis'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7591432, 'lng': 4.1552058},
#                             'viewport': {'northeast': {'lat': 51.76051512989272,
#                                                        'lng': 4.156657779892721},
#                                          'southwest': {'lat': 51.75781547010728,
#                                                        'lng': 4.153958120107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '76a5e4f7a374f2666bcb6d53a4b66e614748c6be',
#                'name': 'bed & breakfast Kantje Levantje',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 918,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101156557871213563787">bed '
#                                                  '&amp; breakfast Kantje '
#                                                  'Levantje</a>'],
#                            'photo_reference': 'CmRaAAAASko6XL9Pig5sFD__sH3wBn8Ef9dErBKNV9GYp0R9JWK5JmxiRaQyvrozI5S-yimSgyZiLeETptFtnlNzPsi9GEDBYQI-SYKDvdz9XPsgyM7WnPeeBSbniDBX0XnUpGh-EhA7djQxTearIfKEeHuugwCpGhRasDJQgBMUnwJuYds7yIHBNrnb1g',
#                            'width': 1632}],
#                'place_id': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'plus_code': {'compound_code': 'Q554+M3 Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q554+M3'},
#                'rating': 4.6,
#                'reference': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'scope': 'GOOGLE',
#                'types': ['real_estate_agency',
#                          'travel_agency',
#                          'lodging',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 49,
#                'vicinity': 'Langeweg 23, Sommelsdijk'}],
#   'status': 'OK'},
#  {'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 47.2147253, 'lng': 15.4188626},
#                             'viewport': {'northeast': {'lat': 47.21608077989271,
#                                                        'lng': 15.42054267989272},
#                                          'southwest': {'lat': 47.21338112010727,
#                                                        'lng': 15.41784302010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '1086684e1eed9ff6574e548501f1c21a5f7c512e',
#                'name': 'Der Trattnerhof',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3450,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/112495068912392273274">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAwKadUbKEjqhvlXKKyE2_t7jc32R7X-qjX-m8zeiuwuz4_vhLrcbEK3D2k_r00E0pk_lhEPV3uO96SDz5uYgU1x_9hTkMKVLr7XyXLYHJ6CvxoNZDGlkUktbflSKt9Q9BEhDPLDTgYPIPQ_vI6EPT8BPtGhSBwFBwTJhJ7xIsJ09LwztvofoFPw',
#                            'width': 5343}],
#                'place_id': 'ChIJs6AJspA5bkcRXuj0-N2Lerk',
#                'plus_code': {'compound_code': '6C79+VG Semriach, Austria',
#                              'global_code': '8FVQ6C79+VG'},
#                'rating': 4.3,
#                'reference': 'ChIJs6AJspA5bkcRXuj0-N2Lerk',
#                'scope': 'GOOGLE',
#                'types': ['spa',
#                          'lodging',
#                          'restaurant',
#                          'food',
#                          'health',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 244,
#                'vicinity': 'Unterer, Windhof 18, Semriach'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 47.2149424, 'lng': 15.4175343},
#                             'viewport': {'northeast': {'lat': 47.21626222989273,
#                                                        'lng': 15.41867837989272},
#                                          'southwest': {'lat': 47.21356257010729,
#                                                        'lng': 15.41597872010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '99203ef6e8223b316d6de625949b68bfd52e03f5',
#                'name': 'Schöcklblick',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3487,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/116457276032808039390">Pension '
#                                                  'Schöcklblick</a>'],
#                            'photo_reference': 'CmRaAAAA67wtgo1B535-GIlMGJsCTxJ0zSDPloQXprb-4WrSFntA6pdV_YFtcYs1-HJbFNoyEQWi2VXXgys12RQliWbkanBD5Afgun3WZefNBqxyNLM-ssdnbF0iH4nQY2gyLFn2EhBdIGxiPQrbHIBKMMMChkYoGhS9Wg_LaX3AHNUkEaCpMUleUkZJNA',
#                            'width': 5230}],
#                'place_id': 'ChIJK4SV8iE6bkcRcETs265MsPg',
#                'plus_code': {'compound_code': '6C79+X2 Semriach, Austria',
#                              'global_code': '8FVQ6C79+X2'},
#                'rating': 4.6,
#                'reference': 'ChIJK4SV8iE6bkcRcETs265MsPg',
#                'scope': 'GOOGLE',
#                'types': ['lodging',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 58,
#                'vicinity': 'Unterer, Windhof 15, Semriach'}],
#   'status': 'OK'},
#  {'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 47.1787607, 'lng': 15.488871},
#                             'viewport': {'northeast': {'lat': 47.18011217989273,
#                                                        'lng': 15.48987857989272},
#                                          'southwest': {'lat': 47.17741252010728,
#                                                        'lng': 15.48717892010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'ce75d63cca9fafbef7b4e3aab8aa06e6a24aef87',
#                'name': 'Pension Seirer',
#                'photos': [{'height': 1836,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108178908475097633630">Алекс '
#                                                  'Гавва</a>'],
#                            'photo_reference': 'CmRaAAAAu_t0ttdtBes3QvPFi-UVtUrcmOiDb5mhixs0xCVEfYZln6aEbXiGksMKs4SX4WW3Z0R1YWKN14ndeuftaMZ7nzHi3GlGW6fsHfez9Zu_9RXKvxEG4iS_RWZhjXxcR8mnEhBI8FEEp2qZKsg1tuLhzRitGhR2KVyK4VCX4zDTjLEIb853sS5F1Q',
#                            'width': 3264}],
#                'place_id': 'ChIJkc2A1_A3bkcRpNnTyZPQzH4',
#                'plus_code': {'compound_code': '5FHQ+GG Sankt Radegund bei '
#                                               'Graz, Austria',
#                              'global_code': '8FVQ5FHQ+GG'},
#                'rating': 4.7,
#                'reference': 'ChIJkc2A1_A3bkcRpNnTyZPQzH4',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 106,
#                'vicinity': 'Kalvarienbergstraße 11, St. Radegund bei Graz'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 47.2147253, 'lng': 15.4188626},
#                             'viewport': {'northeast': {'lat': 47.21608077989271,
#                                                        'lng': 15.42054267989272},
#                                          'southwest': {'lat': 47.21338112010727,
#                                                        'lng': 15.41784302010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '1086684e1eed9ff6574e548501f1c21a5f7c512e',
#                'name': 'Der Trattnerhof',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3450,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/112495068912392273274">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAloUO94faxL_OckVOgd69gRRS5TP2fI4slQWVQhH0I6SxgRcitXzpU25Y54ZIvcY4NRuy8J6aBG3swv6mJXJ61lWNB7dFHtUkF2QvNkaeSQ8_iAjcZK0tATxUGN51T9suEhCD4_usmd_f4by2U2fZqt7tGhR5fEdRNUkCoYEUf_ZpEFB8bYJIVw',
#                            'width': 5343}],
#                'place_id': 'ChIJs6AJspA5bkcRXuj0-N2Lerk',
#                'plus_code': {'compound_code': '6C79+VG Semriach, Austria',
#                              'global_code': '8FVQ6C79+VG'},
#                'rating': 4.3,
#                'reference': 'ChIJs6AJspA5bkcRXuj0-N2Lerk',
#                'scope': 'GOOGLE',
#                'types': ['spa',
#                          'lodging',
#                          'restaurant',
#                          'food',
#                          'health',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 244,
#                'vicinity': 'Unterer, Windhof 18, Semriach'}],
#   'status': 'OK'},
#  {'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.7121529, 'lng': 15.536365},
#                             'viewport': {'northeast': {'lat': 46.71357397989272,
#                                                        'lng': 15.53765012989272},
#                                          'southwest': {'lat': 46.71087432010728,
#                                                        'lng': 15.53495047010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '8c9d594417a698d1d5b6bf96ebe45f8f3c579bcc',
#                'name': 'Hotel Villa Rosa',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2988,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/103298475303101343767">Ingrid '
#                                                  'Gondosch</a>'],
#                            'photo_reference': 'CmRaAAAArvqO_gX6rKtzDLofWMATTsCPuZnN0k5jLFRIvcprkH8YL1PGPt1h7XhTpox3fXXOVHEDcCq2AvejX6K4My1cSQnqnem16TxXF3IQ4DOooGJEmWaZ3f1Mdm0-BFWyF5sWEhDuZXYFtJ85N88kG_6flZfxGhRZmHQn9xfpDJTiymgqt36UBR5zxQ',
#                            'width': 5312}],
#                'place_id': 'ChIJyS0jum-ib0cRAqq4_SYo03o',
#                'plus_code': {'compound_code': 'PG6P+VG Sernau, Austria',
#                              'global_code': '8FRQPG6P+VG'},
#                'rating': 4.9,
#                'reference': 'ChIJyS0jum-ib0cRAqq4_SYo03o',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 47,
#                'vicinity': 'Sernau 8, Sernau'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.667732, 'lng': 15.468271},
#                             'viewport': {'northeast': {'lat': 46.66907967989273,
#                                                        'lng': 15.46956877989272},
#                                          'southwest': {'lat': 46.66638002010728,
#                                                        'lng': 15.46686912010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'c030b39f905e04d535bd0bd2d5318d0dad1d7a42',
#                'name': 'Tscheppes Lang-Gasthof',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1152,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/100970786528942353494">Tscheppes '
#                                                  'Lang-Gasthof</a>'],
#                            'photo_reference': 'CmRaAAAAeRlNwtoIqTJuN9nq8sH42gUkz9pNarfPSYwrvlzYktlQO6BxZAHecAozgWuK_FfTB13ihGPHWFU00UFvnazFYZSTfloMuqOiqhxz57Jd7EWuBze6y_UPnliy6eICwLpDEhA7FbLwgmgla9PT_SGUDujJGhTzpym7Br-FQMZzRK_NBDCS2fApQw',
#                            'width': 2048}],
#                'place_id': 'ChIJ726ZhLWZb0cRZc5ifGTZ2kQ',
#                'plus_code': {'compound_code': 'MF99+38 Leutschach, Austria',
#                              'global_code': '8FRQMF99+38'},
#                'rating': 4.4,
#                'reference': 'ChIJ726ZhLWZb0cRZc5ifGTZ2kQ',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 182,
#                'vicinity': 'Hauptpl. 6, Leutschach'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.6237746, 'lng': 15.4834332},
#                             'viewport': {'northeast': {'lat': 46.62515177989271,
#                                                        'lng': 15.48475947989272},
#                                          'southwest': {'lat': 46.62245212010727,
#                                                        'lng': 15.48205982010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'fc8b632e006ffa5eee37748df00432a22ac76a40',
#                'name': 'Hotel Restaurant Moserhof',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1836,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/106293488637646865481">MrDriver '
#                                                  'YouTube</a>'],
#                            'photo_reference': 'CmRaAAAAYwHEZ9TA8Z4DE8dDmz7Lu9ZeS8sUOMbcDXxnpuH-DVkuYHMig0ZfIZoxMKM02kjTyupl5L3KHMiv4ADp1d1edjdZ9O_b5z4f3SmCgcMOVHff-x0YC6wiUISamIzxiRi6EhBTzu6YeDf7Pcs9AWdnw9d8GhQV3Q5ozwG7kGfVTzFLSrPyMxo3Cw',
#                            'width': 3264}],
#                'place_id': 'ChIJNSNmtNCbb0cR0hiw5vaC9Vo',
#                'plus_code': {'compound_code': 'JFFM+G9 Schloßberg, Austria',
#                              'global_code': '8FRQJFFM+G9'},
#                'rating': 4.2,
#                'reference': 'ChIJNSNmtNCbb0cR0hiw5vaC9Vo',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 6,
#                'vicinity': 'Großwalz 80, Schloßberg'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.6674726, 'lng': 15.4676976},
#                             'viewport': {'northeast': {'lat': 46.66880487989273,
#                                                        'lng': 15.46904032989273},
#                                          'southwest': {'lat': 46.66610522010728,
#                                                        'lng': 15.46634067010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#                'id': 'ec54cae675d1e6515243d0c5b2a83a32c7f15092',
#                'name': 'Liepert´s Kulinarium',
#                'photos': [{'height': 3840,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/110996967323519590981">Lieperts '
#                                                  'Kulinarium</a>'],
#                            'photo_reference': 'CmRaAAAArHYxVvIQlV-8Rfl9fRCfn_vvnDrFFWkL_kHgklU9RBujbkmpJk4y-wsRWthExhy5jDxNQnxHYS3Gv_xGEnwk7DC6UXeuwERAa_6RpJstUwVUxbVqHcj6IRtp57cqIH3FEhBft9RKXFBLFkEMijJH1Ju4GhS-37t7apdJzIQ0ayJrz1UdJbAIWg',
#                            'width': 5760}],
#                'place_id': 'ChIJtcHEcMqZb0cRfN15RImk2UE',
#                'plus_code': {'compound_code': 'MF89+X3 Leutschach, Austria',
#                              'global_code': '8FRQMF89+X3'},
#                'rating': 4.8,
#                'reference': 'ChIJtcHEcMqZb0cRfN15RImk2UE',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'lodging',
#                          'bar',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 70,
#                'vicinity': 'Arnfelser Str. 2, Leutschach'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.6237746, 'lng': 15.4834332},
#                             'viewport': {'northeast': {'lat': 46.62515177989271,
#                                                        'lng': 15.48475947989272},
#                                          'southwest': {'lat': 46.62245212010727,
#                                                        'lng': 15.48205982010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#                'id': '43013b916e37077591ae2f7909d000a412785107',
#                'name': 'Boutique Hotel Moserhof Südsteiermark',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 1365,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/110051427325452557206">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAnrK_gVCUNSsufaXczftXVmjMrGxT54QAh-ZACfeR0ruFqJ-oYbtinC6RSAt7ov3wBePVCGzKECjCc1XmXPpWS7KRKevHsXzIWpF-Kz05JObBjcWRpJp9pEWneXKVerE-EhDgMO2RizhBhMYndq_yP-4uGhSy5HhgOLzh05nurQb3d6Yb7yEXDg',
#                            'width': 2048}],
#                'place_id': 'ChIJNSNmtNCbb0cRlfXodnLqyE0',
#                'plus_code': {'compound_code': 'JFFM+G9 Leutschach, Austria',
#                              'global_code': '8FRQJFFM+G9'},
#                'rating': 4.4,
#                'reference': 'ChIJNSNmtNCbb0cRlfXodnLqyE0',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'lodging',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 122,
#                'vicinity': 'Großwalz 80, Schloßberg'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.6728588, 'lng': 15.5349288},
#                             'viewport': {'northeast': {'lat': 46.67444057989272,
#                                                        'lng': 15.53632952989272},
#                                          'southwest': {'lat': 46.67174092010728,
#                                                        'lng': 15.53362987010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#                'id': 'c893991040557ebadb5de2cfb576145f639de04c',
#                'name': 'Weingut Hotel Restaurant Mahorko',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2133,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/103416907121074250067">Weingut '
#                                                  'Hotel Restaurant '
#                                                  'Mahorko</a>'],
#                            'photo_reference': 'CmRaAAAAA1C9pM8craU4Zx1wLfdQA_Fr0BYJHuTPOyCsjTM2LRuPmXtOva4U9Wn5Plq44oprILGTgiostew50GCXqoBAdxqgAcdezNIxW7LzNW4dUk17JtW3_ufC4E8-fB0YOeHuEhAW8SvWBWcZd3lYVW19NuWmGhSvBSkmQF8Vk4jeFlYJPizXf980kQ',
#                            'width': 3200}],
#                'place_id': 'ChIJz5Lm_iqZb0cRViNMF5ajmNY',
#                'plus_code': {'compound_code': 'MGFM+4X Glanz an der '
#                                               'Weinstraße, Austria',
#                              'global_code': '8FRQMGFM+4X'},
#                'rating': 4.5,
#                'reference': 'ChIJz5Lm_iqZb0cRViNMF5ajmNY',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'lodging',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 271,
#                'vicinity': 'Glanz 82, Glanz an der Weinstraße'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.6438378, 'lng': 15.5138514},
#                             'viewport': {'northeast': {'lat': 46.64529597989272,
#                                                        'lng': 15.51507817989273},
#                                          'southwest': {'lat': 46.64259632010727,
#                                                        'lng': 15.51237852010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '8317bab6fdac8e33286ee0f583c82c7192c33327',
#                'name': 'Gut Pössnitzberg',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1500,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/106545070174805506432">Gut '
#                                                  'Pössnitzberg</a>'],
#                            'photo_reference': 'CmRaAAAAaRKzf7nT2O4DRtKDAVTjQr6wkwlk6yjer6guZ0EKc-C_xqPdKYxkLi0rnguM758ViutHVqpvwYoxKtWTwrnmtx_gHozIWZfmq52XN7Ukq-iEDxy5we8sFv2ruElhpDM_EhCh3abIT20Dbiay3CQ_YgJHGhSQ0fYdfF5dQVNMgrKP3QlXxoVKXg',
#                            'width': 2246}],
#                'place_id': 'ChIJrxxfhUCZb0cRO7E9CbMs7yw',
#                'plus_code': {'compound_code': 'JGV7+GG Leutschach, Austria',
#                              'global_code': '8FRQJGV7+GG'},
#                'rating': 4.6,
#                'reference': 'ChIJrxxfhUCZb0cRO7E9CbMs7yw',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 271,
#                'vicinity': 'Pößnitz 168, Leutschach'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 46.6708675, 'lng': 15.4228098},
#                             'viewport': {'northeast': {'lat': 46.67225492989272,
#                                                        'lng': 15.42416167989272},
#                                          'southwest': {'lat': 46.66955527010727,
#                                                        'lng': 15.42146202010728}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '2805f6a4d8f8b9263d2275921703144206edbc48',
#                'name': 'Gasthof-Hotel Schmied',
#                'photos': [{'height': 3024,
#                            'html_attributions': ['<a '
# ...
#                                                  'Vandenhautte</a>'],
#                            'photo_reference': 'CmRaAAAAqdvzPy73fOfx_GLsutN2Bn1lHg1U2gLOhT3aKDFX5JGt1vZ27R8v0DGXpLC1z17JIEF-tb5D0SBMKTLp-pRMe9xXzT0rIvx7EAqfKQJOgFtdavSsTCBTpyfCLro3pB3fEhB23i9_NdtXZZdz8M2XN4uMGhQmSRA0ltvvPqnXVpmEumFHM4mKyw',
#                            'width': 1272}],
#                'place_id': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'plus_code': {'compound_code': 'Q46V+XQ Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q46V+XQ'},
#                'rating': 4.6,
#                'reference': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 12,
#                'vicinity': 'Prutweg 6, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.759176, 'lng': 4.165355},
#                             'viewport': {'northeast': {'lat': 51.76051227989272,
#                                                        'lng': 4.166822879892722},
#                                          'southwest': {'lat': 51.75781262010728,
#                                                        'lng': 4.164123220107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '8430829538aaa4b355a4c3f32c982c39932ccb26',
#                'name': 'De Oude Bank',
#                'photos': [{'height': 960,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/105173598034239957349">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAa7_QcC1c6du7FC0qOgy-yAnFUbSumadiI4XmAmhVn01NThceCBSPGNhNghmZzSfbHJX-edkCvcVUaJ1Kjib1_8yXyCSpnaCnvHNk84qcCA8z5lvD0NHEvTPFdT-OzcKjEhB5kOQouZo9AB7hoyhpqHn-GhTkWJ-IsbyaJtVhaYFu1RjY2K81HQ',
#                            'width': 1440}],
#                'place_id': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'plus_code': {'compound_code': 'Q558+M4 Middelharnis, '
#                                               'Netherlands',
#                              'global_code': '9F36Q558+M4'},
#                'rating': 4.6,
#                'reference': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 15,
#                'vicinity': 'Voorstraat 33, Middelharnis'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7591432, 'lng': 4.1552058},
#                             'viewport': {'northeast': {'lat': 51.76051512989272,
#                                                        'lng': 4.156657779892721},
#                                          'southwest': {'lat': 51.75781547010728,
#                                                        'lng': 4.153958120107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '76a5e4f7a374f2666bcb6d53a4b66e614748c6be',
#                'name': 'bed & breakfast Kantje Levantje',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 918,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101156557871213563787">bed '
#                                                  '&amp; breakfast Kantje '
#                                                  'Levantje</a>'],
#                            'photo_reference': 'CmRaAAAATrf3ZtwbzvX9HIIs1R9dWu1pM09b3Sj6bDuKfy8a1yAvGmFk4fZfBZ5yrnJZghu3OUzpSl5mnRt39BElULJYTYf1P6MSTaQ6cseRlXGJxoi1CU_nBIcQWbdPr_zGHZx1EhAE8KauSX9BZFc7IaqDB6HoGhSg_9WKH4ZWHAJ9OPw_CYX1Z-fYug',
#                            'width': 1632}],
#                'place_id': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'plus_code': {'compound_code': 'Q554+M3 Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q554+M3'},
#                'rating': 4.6,
#                'reference': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'scope': 'GOOGLE',
#                'types': ['real_estate_agency',
#                          'travel_agency',
#                          'lodging',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 49,
#                'vicinity': 'Langeweg 23, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.70968000000001,
#                                          'lng': 4.078116},
#                             'viewport': {'northeast': {'lat': 51.71101127989272,
#                                                        'lng': 4.079462079892722},
#                                          'southwest': {'lat': 51.70831162010728,
#                                                        'lng': 4.076762420107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'c1a3c0d012ff614e38c61b53380f3bf53d4eb4b5',
#                'name': 'Peaceful Holiday Home in South Holland by the Lake',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 683,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/109563002916394204876">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAATfioPoZa4hhIpp3SelxKdPMy57aUi102Ns1GMl6X3-mCNlfahhiztbgcCt5MpqZB12Mtx0hqYQH3Ve_9j2Qx2jRskXbn0b34fXsKjInxJy9NoekxvxKchA87iI5M2M_jEhA9hxnrsw1cm3ab2UZfjbacGhSEl4DDrWKzRJ_1OQLPFrE9BtkiOw',
#                            'width': 1214}],
#                'place_id': 'ChIJbYhY7s1bxEcRK7kSpyJQJIw',
#                'plus_code': {'compound_code': 'P35H+V6 Herkingen, Netherlands',
#                              'global_code': '9F36P35H+V6'},
#                'rating': 4.5,
#                'reference': 'ChIJbYhY7s1bxEcRK7kSpyJQJIw',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 2,
#                'vicinity': 'Herkingsezeedijk 226, Herkingen'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7508875,
#                                          'lng': 4.097790499999999},
#                             'viewport': {'northeast': {'lat': 51.75215567989272,
#                                                        'lng': 4.099160479892721},
#                                          'southwest': {'lat': 51.74945602010728,
#                                                        'lng': 4.096460820107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': 'da24a88bd490a600632e2270929cc23a0aafcf33',
#                'name': 'Bed & Breakfast Groenewege',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3024,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/114478124704923928536">Ad '
#                                                  'Hoen</a>'],
#                            'photo_reference': 'CmRaAAAAos6q5K0Odi_4pgznhCyAyTiSNLxE8PySjQrqZKIumEYBHU05GIWXAVXGjgyIDFOOnLHusORfdkVhzFh3_q-xi5c45iyI2tGfCCy2o1_u_tkyzwajZYo2C9udfrN2VSj3EhBJFct3EgzOS2EaQaP4Hbb_GhStBLdEGUGGdJkP87WasoXwFoCFqA',
#                            'width': 4032}],
#                'place_id': 'ChIJbRlnwfBaxEcRWdMmsQtZIyU',
#                'plus_code': {'compound_code': 'Q32X+94 Dirksland, Netherlands',
#                              'global_code': '9F36Q32X+94'},
#                'rating': 4.8,
#                'reference': 'ChIJbRlnwfBaxEcRWdMmsQtZIyU',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 12,
#                'vicinity': 'Boezemweg 62, Dirksland'}],
#   'status': 'OK'},
#  {'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7490935,
#                                          'lng': 4.103901899999999},
#                             'viewport': {'northeast': {'lat': 51.75046792989272,
#                                                        'lng': 4.105310929892721},
#                                          'southwest': {'lat': 51.74776827010728,
#                                                        'lng': 4.102611270107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#                'id': 'db836ecacea72f2e7225c772394dabe3e1fb20b4',
#                'name': 'De Snoeperij',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 4608,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/107687817201519942100">edith</a>'],
#                            'photo_reference': 'CmRaAAAAb1nEBZFCT0BFxlImFjV413Ggru7wLv9ZE25qSvvuGEvIZEEsipMtrhpr7-s5dupAvasIcgLaS2_cEY06szYjvbECMd5owLww__gG_7rZXKOCV4YcsjnTSts37G_7msWLEhAZ9snOdjOFs0NAEVqrmOurGhSNcEJlEvk8B47BEGTjj7LCoHAeOA',
#                            'width': 3456}],
#                'place_id': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'plus_code': {'compound_code': 'P4X3+JH Dirksland, Netherlands',
#                              'global_code': '9F36P4X3+JH'},
#                'rating': 4.4,
#                'reference': 'ChIJqRgPX-VaxEcRuLPr4TeHYYA',
#                'scope': 'GOOGLE',
#                'types': ['cafe',
#                          'lodging',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 77,
#                'vicinity': 'Straatdijk 2, Dirksland'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.76240929999999,
#                                          'lng': 4.144411},
#                             'viewport': {'northeast': {'lat': 51.76388062989272,
#                                                        'lng': 4.145470829892722},
#                                          'southwest': {'lat': 51.76118097010728,
#                                                        'lng': 4.142771170107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '36e1eafd5f39844f628fc8cd7d01468ce837e0a1',
#                'name': 'Sommelsdijk',
#                'photos': [{'height': 1884,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108895009111372736249">Josiane '
#                                                  'Vandenhautte</a>'],
#                            'photo_reference': 'CmRaAAAAA14vLsrhngyGuPoMqEGgvlT1xbguN4FK0kNt9BQMQ2CLaDqIZvdCgScYoT-7i5DzeOwMMDWV9qY-iLfsNELGi1wqEBl41HQUkVUAAqWXOOdsX_8ACGB1y72ZHysQZNdpEhC2-Ph4s7jO8UfoDcInOLUiGhToI9ni-a8T9nzmbW0YiByNTgHF6g',
#                            'width': 1272}],
#                'place_id': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'plus_code': {'compound_code': 'Q46V+XQ Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q46V+XQ'},
#                'rating': 4.6,
#                'reference': 'ChIJrZc8QUtFxEcRr7SBdgcdxsc',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 12,
#                'vicinity': 'Prutweg 6, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.7591432, 'lng': 4.1552058},
#                             'viewport': {'northeast': {'lat': 51.76051512989272,
#                                                        'lng': 4.156657779892721},
#                                          'southwest': {'lat': 51.75781547010728,
#                                                        'lng': 4.153958120107277}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '76a5e4f7a374f2666bcb6d53a4b66e614748c6be',
#                'name': 'bed & breakfast Kantje Levantje',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 918,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101156557871213563787">bed '
#                                                  '&amp; breakfast Kantje '
#                                                  'Levantje</a>'],
#                            'photo_reference': 'CmRaAAAAPfimyRwHW4JP8T9qWS5OZO_FUYb7sMbdc5_EcTuhSbPxYcfNBCJGt6ghgQ5WsjqwS4otiIEevxw-XTRhzrVMg0u03mBpRu76G35SyqbuV8R5zbDasleuEIQ6qVhDhhnQEhCMQ-10a7puKI3B7X3DRkY8GhQPE98m1QMtZDxObdROQoKKVj6Tmw',
#                            'width': 1632}],
#                'place_id': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'plus_code': {'compound_code': 'Q554+M3 Sommelsdijk, '
#                                               'Netherlands',
#                              'global_code': '9F36Q554+M3'},
#                'rating': 4.6,
#                'reference': 'ChIJbyoxC0hFxEcRoWNbUz2UrYk',
#                'scope': 'GOOGLE',
#                'types': ['real_estate_agency',
#                          'travel_agency',
#                          'lodging',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 49,
#                'vicinity': 'Langeweg 23, Sommelsdijk'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 51.759176, 'lng': 4.165355},
#                             'viewport': {'northeast': {'lat': 51.76051227989272,
#                                                        'lng': 4.166822879892722},
#                                          'southwest': {'lat': 51.75781262010728,
#                                                        'lng': 4.164123220107278}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#                'id': '8430829538aaa4b355a4c3f32c982c39932ccb26',
#                'name': 'De Oude Bank',
#                'photos': [{'height': 960,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/105173598034239957349">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'CmRaAAAAgLT1DahMQtmn6WZNEnbMnN5rzVa8lznd7oLNMXL1DCZgWqn3bHi81XdMp7K5N-5QVWHN-nZCgNwdTZyIFRFaI8PpDWvJYQDJbYsHeG1ezVHRmRKvMpy58HDodZcsXDBwEhChsX2tfZfuK6clscQ_l4D8GhR03FMPTDGPYulOxmfbsIatFWTu_w',
#                            'width': 1440}],
#                'place_id': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'plus_code': {'compound_code': 'Q558+M4 Middelharnis, '
#                                               'Netherlands',
#                              'global_code': '9F36Q558+M4'},
#                'rating': 4.6,
#                'reference': 'ChIJ__8uWUBFxEcR_M4kG_WqZds',
#                'scope': 'GOOGLE',
#                'types': ['lodging', 'point_of_interest', 'establishment'],
#                'user_ratings_total': 15,
#                'vicinity': 'Voorstraat 33, Middelharnis'}],
#   'status': 'OK'}]

# %%
h_name = []
h_city = []
h_loc = []
for x in hotel_data:
    h_name.append(x['results'][0]['name'])
    h_city.append(x['results'][0]['plus_code']['compound_code'])
    h_loc.append((float( x['results'][0]['geometry']['location']['lat'] ) , float( x['results'][0]['geometry']['location']['lng'] ) ))

# %%
print(h_name)
print(h_city)
print(h_loc)
# Out:
# ['De Snoeperij', 'De Snoeperij', 'De Snoeperij', 'Der Trattnerhof', 'Pension Seirer', 'Hotel Villa Rosa', 'Hotel Villa Rosa', 'De Snoeperij', 'De Snoeperij']
# ['P4X3+JH Dirksland, Netherlands', 'P4X3+JH Dirksland, Netherlands', 'P4X3+JH Dirksland, Netherlands', '6C79+VG Semriach, Austria', '5FHQ+GG Sankt Radegund bei Graz, Austria', 'PG6P+VG Sernau, Austria', 'PG6P+VG Sernau, Austria', 'P4X3+JH Dirksland, Netherlands', 'P4X3+JH Dirksland, Netherlands']
# [(51.7490935, 4.103901899999999), (51.7490935, 4.103901899999999), (51.7490935, 4.103901899999999), (47.2147253, 15.4188626), (47.1787607, 15.488871), (46.7121529, 15.536365), (46.7121529, 15.536365), (51.7490935, 4.103901899999999), (51.7490935, 4.103901899999999)]

# %%
rcount = 0
names = []
for i in h_name:
    hotel_pinn = [{
        "name": h_name
        , "Zip, City, Country" : h_city
        , "location" : h_loc
    }]
    rcount += 1
pprint(hotel_pinn)
# Out:
# [{'Zip, City, Country': ['P4X3+JH Dirksland, Netherlands',
#                          'P4X3+JH Dirksland, Netherlands',
#                          'P4X3+JH Dirksland, Netherlands',
#                          '6C79+VG Semriach, Austria',
#                          '5FHQ+GG Sankt Radegund bei Graz, Austria',
#                          'PG6P+VG Sernau, Austria',
#                          'PG6P+VG Sernau, Austria',
#                          'P4X3+JH Dirksland, Netherlands',
#                          'P4X3+JH Dirksland, Netherlands'],
#   'location': [(51.7490935, 4.103901899999999),
#                (51.7490935, 4.103901899999999),
#                (51.7490935, 4.103901899999999),
#                (47.2147253, 15.4188626),
#                (47.1787607, 15.488871),
#                (46.7121529, 15.536365),
#                (46.7121529, 15.536365),
#                (51.7490935, 4.103901899999999),
#                (51.7490935, 4.103901899999999)],
#   'name': ['De Snoeperij',
#            'De Snoeperij',
#            'De Snoeperij',
#            'Der Trattnerhof',
#            'Pension Seirer',
#            'Hotel Villa Rosa',
#            'Hotel Villa Rosa',
#            'De Snoeperij',
#            'De Snoeperij']}]

# %%
h_dict = [{
    "Name" : 'De Snoeperi', "location" : (51.7490935, 4.103901899999999), "City" : "Dirksland", "Country" : "Netherlands",
    "Name" : 'Der Trattnerhof', "location" : (47.2147253, 15.4188626), "City" : "Semriach", "Country" : "Austria",
    "Name" : 'Pension Seirer', "location" : (47.1787607, 15.488871), "City" : "Sankt Radegund bei Graz", "Country" : "Austria",
    "Name" : 'Hotel Villa Rosa', "location" : (46.7121529, 15.536365), "City" : "Sernau", "Country" : "Austria",
    "Name" : 'De Snoeperij', "location" : (51.7490935, 4.103901899999999), "City" : "Dirksland", "Country" : "Netherlands"
}]
h_locations = [h['location'] for h in h_dict]
info_box_template = """
<dl>
<dt>Name</dt><dd>{Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
h_info = [info_box_template.format(**h) for h in h_dict]

# %%
marker_layer1 = gmaps.marker_layer(h_locations, info_box_content = h_info)

# %%
fig.add_layer(marker_layer1)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
